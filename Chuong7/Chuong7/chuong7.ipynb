# %% [markdown]
#  Phan Ngọc Thảo Nguyên    |     3124411193

# %% [markdown]
# ## Chạy chương trình và hiển thị kết quả:

# %% [markdown]
# ## BÀI 1: Tìm cây khung DFS

# %% [markdown]
# input: 6 6
# 1 2
# 1 3
# 1 6
# 2 4
# 2 5
# 5 6

# %% [markdown]
# output:
# 5
# 1 2
# 2 4
# 2 5
# 5 6
# 1 3

# %%
import subprocess

# Biên dịch file C++
subprocess.run(["g++", "CAYKHUNG_DFS.cpp", "-o", "CAYKHUNG_DFS"])

# Tạo file input mẫu
with open("caykhung.inp", "w") as f:
    f.write("""6 6
1 2
1 3
1 6
2 4
2 5
5 6
""")

# Chạy chương trình
subprocess.run(["./CAYKHUNG_DFS"])

# Đọc và hiển thị kết quả
print("📤 **Kết quả chạy thử:**\n")
with open("caykhung.out") as f:
    print(f.read())
# Out:
# 📤 **Kết quả chạy thử:**
#
# 5
# 1 2
# 2 4
# 2 5
# 5 6
# 1 3

# %% [markdown]
# ## Bài 2: Tìm cây khung BFS

# %% [markdown]
# input
# 6 6
# 1 2
# 1 3
# 1 6
# 2 4
# 2 5
# 5 6

# %% [markdown]
# output:
# 5
# 1 2
# 1 3
# 1 6
# 2 4
# 2 5

# %%
import subprocess

# --- Bước 1: Biên dịch file C++ ---
compile_result = subprocess.run(["g++", "CAYKHUNG_BFS.cpp", "-o", "CAYKHUNG_BFS"], capture_output=True, text=True)



    # --- Bước 2: Tạo file input ---
with open("caykhung.inp", "w") as f:
        f.write("""6 6
1 2
1 3
1 6
2 4
2 5
5 6
""")


    # --- Bước 3: Chạy chương trình ---
run_result = subprocess.run(["./CAYKHUNG_BFS"], capture_output=True, text=True)


print("🧩 **Kết quả chạy thử:**\n")

        # --- Bước 4: Đọc file output ---
try:
            with open("caykhung.out", "r") as f:
                output = f.read()
                print(output)
except FileNotFoundError:
            print("⚠️ Không tìm thấy file caykhung.out, in ra stdout:\n")
            print(run_result.stdout)
# Out:
# 🧩 **Kết quả chạy thử:**
#
# 5
# 1 2
# 1 3
# 1 6
# 2 4
# 2 5

# %% [markdown]
# ## Bài 3: Kruskal

# %% [markdown]
# input
# 7 12
# 1 2 8
# 1 3 5
# 2 3 10
# 2 4 2
# 2 5 18
# 3 4 3
# 3 6 16
# 4 5 12
# 4 6 30
# 4 7 14
# 5 7 4
# 6 7 26

# %% [markdown]
# output
# 6 42
# 2 4 2
# 3 4 3
# 5 7 4
# 1 3 5
# 4 5 12
# 3 6 16

# %%
import subprocess

# --- Biên dịch file C++ ---

subprocess.run(["g++", "KRUSKAL.cpp", "-o", "KRUSKAL"])


# --- Tạo file input ---
with open("kruskal.inp", "w") as f:
    f.write("""7 12
1 2 8
1 3 5
2 3 10
2 4 2
2 5 18
3 4 3
3 6 16
4 5 12
4 6 30
4 7 14
5 7 4
6 7 26
""")



# --- Chạy chương trình và BẮT KẾT QUẢ TỪ STDOUT ---
run_result = subprocess.run(
    ["./KRUSKAL"], 
    input=open("kruskal.inp").read(), 
    text=True,
    capture_output=True  # BẮT (CAPTURER) output từ stdout của chương trình C++
)

# --- Hiển thị kết quả ---
print("\n **Kết quả chạy thử:**")



print(run_result.stdout)
# Out:
#  **Kết quả chạy thử:**
# 6 42
# 2 4 2
# 3 4 3
# 5 7 4
# 1 3 5
# 4 5 12
# 3 6 16
